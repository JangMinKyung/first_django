# %%
image_url = "https://images.pexels.com/photos/36753/flower-purple-lical-blosso.jpg?auto=compress&cs=tinysrgb&dpr=1&w=500"

# %%
import requests

image_binary = requests.get(image_url).content

with open("flower.jpg", "wb") as f:
    f.write(image_binary)

# %%
from PIL import Image 

flower_image = Image.open("flower.jpg")

# %%
flower_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x331 at 0x27AF1C86588>

# %%
from pilkit.processors import Thumbnail

processor = Thumbnail(width=300, height=300)

# %%
thumb_image = processor.process(flower_image)

# %%
thumb_image
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x27AF2D58208>

# %%
thumb_image.save("thumb-300x300.png")
